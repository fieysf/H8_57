# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from IPython.display import Math, Latex
from IPython.core.display import Image
from scipy.stats import uniform, norm, gamma, expon, poisson, binom, bernoulli

# %%
def plot_distribution(data, title):
    sns.displot(
        data,
        bins=100,
        kde=True,
        color="skyblue",
        linewidth=15,
        alpha=1
    )
    ax.set(xlabel=title, ylabel="Frequency")
    plt.title(title)
    plt.show()

# %%
# uniform distribution
rv_uniform = uniform.rvs(loc=100, scale=10, size=20)

sns.displot(rv_uniform, color="skyblue", linewidth=1.5, alpha=1, kde=True)
ax.set(xlabel="Uniform Distribution", ylabel="Frequency")
plt.show()

# %%
# Normal distribution
rv_normal = norm.rvs(loc=100, scale=10, size=20)

sns.displot(rv_normal,
    bins=100,
    kde=True,
    color="skyblue",
    linewidth=15,
    alpha=1
)
ax.set(xlabel="Normal Distribution", ylabel="Frequency")
plt.show()

# %%
# Gamma distribution
n = 10000
a = 1
loc = 5
scale = 10
rv_gamma = gamma.rvs(a=a, loc=loc, scale=scale, size=n)
plot_distribution(rv_gamma, f"Gamma Distribution (a={a}, loc={loc}, scale={scale})")

# %%
# Exponential Distribution
n = 10000
loc = 0
scale = 1
rv_exponential = expon.rvs(scale=scale, loc=loc, size=n)
plot_distribution(rv_exponential, "")

# %%
# Poisson
size = 10000
mu = 3
rv_poisson = poisson.rvs(mu=mu, size=size)
plot_distribution(rv_poisson, "Poisson Distribution")

# %%
fig = plt.figure(figsize=(12, 6))

sns.displot(rv_uniform, color="skyblue", linewidth=1.5, alpha=1, kde=True, ax=ax1)
sns.displot(rv_normal,bins=100,kde=True,color="skyblue",linewidth=15,alpha=1, ax=ax2)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
