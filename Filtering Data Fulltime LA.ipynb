# %%
import pandas as pd
import numpy as np

# %%
ftla_df = pd.read_csv('Downloads/FulltimeLA.csv')
ftla_df.head(200)
# Out:
#                                               position  \
# 0    Institutional Review Board Analyst I - Office ...
# 1                               Analyst - Optimization
# 2                      Postdoctoral Research Associate
# 3                                     Research Analyst
# 4             Additive Materials and Process Scientist
# ..                                                 ...
# 195                          Laboratory Assistant (PM)
# 196                        Sr. Client Services Manager
# 197                                 Front End Engineer
# 198                          Senior Research Associate
# 199                                Marketing Scientist
#
#                          company  \
# 0                            USC
# 1    The Boston Consulting Group
# 2                            USC
# 3     SHIELDS for Families, Inc.
# 4                   Divergent 3D
# ..                           ...
# 195       Olympia Medical Center
# ...

# %%
ftla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     254 non-null    object
#  1   company      254 non-null    object
#  2   description  254 non-null    object
#  3   numreview    168 non-null    object
#  4   location     254 non-null    object
# dtypes: object(5)
# memory usage: 10.0+ KB

# %%
ftla_df.loc[1]
# Out:
# position                                  Analyst - Optimization
# company                              The Boston Consulting Group
# description    <span id="job_summary" class="summary"><div><b...
# numreview                                            198 reviews
# location                                         Los Angeles, CA
# Name: 1, dtype: object

# %%
ftla_df.drop(['description'], axis = 1, inplace = True)
ftla_df.head(2)
# Out:
#                                             position  \
# 0  Institutional Review Board Analyst I - Office ...
# 1                             Analyst - Optimization
#
#                        company    numreview         location
# 0                          USC  545 reviews  Los Angeles, CA
# 1  The Boston Consulting Group  198 reviews  Los Angeles, CA

# %%
ftla_df.describe()
# Out:
#               position       company    numreview         location
# count              254           254          168              254
# unique             219           134           57               21
# top     Data Scientist  Cedars-Sinai  661 reviews  Los Angeles, CA
# freq                14            24           32              187

# %%
condition = ftla_df['location'] == 'Los Angeles, Ca'
print(condition)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 249    False
# 250    False
# 251    False
# 252    False
# 253    False
# Name: location, Length: 254, dtype: bool

# %%
ftla_df.company
# Out:
# position
# Institutional Review Board Analyst I - Office of Research                            USC
# Analyst - Optimization                                       The Boston Consulting Group
# Postdoctoral Research Associate                                                      USC
# Research Analyst                                              SHIELDS for Families, Inc.
# Additive Materials and Process Scientist                                    Divergent 3D
#                                                                         ...
# Postdoctoral Scientist - PET/CT Angiography Imaging                         Cedars-Sinai
# Postdoctoral Scientist - Surgery / Urologu                   Cedars-Sinai Medical Center
# Market Research Analyst                                              Penn Schoen Berland
# Market Research Business Analyst                                   Kantar Millward Brown
# Product Manager - Tenable Research                                               Tenable
# ...

# %%
ftla_df
# Out:
#                                                                         company  \
# position
# Institutional Review Board Analyst I - Office o...                          USC
# Analyst - Optimization                              The Boston Consulting Group
# Postdoctoral Research Associate                                             USC
# Research Analyst                                     SHIELDS for Families, Inc.
# Additive Materials and Process Scientist                           Divergent 3D
# ...                                                                         ...
# Postdoctoral Scientist - PET/CT Angiography Ima...                 Cedars-Sinai
# Postdoctoral Scientist - Surgery / Urologu          Cedars-Sinai Medical Center
# Market Research Analyst                                     Penn Schoen Berland
# Market Research Business Analyst                          Kantar Millward Brown
# Product Manager - Tenable Research                                      Tenable
#
# ...

# %%
ftla_df.index.name=None

# %%
print(ftla_df.loc['Research Analyst'])
# Out:
#                                             company  \
# Research Analyst         SHIELDS for Families, Inc.
# Research Analyst              Investigative Company
# Research Analyst                Cushman & Wakefield
# Research Analyst  Volunteers of America Los Angeles
# Research Analyst               The Expert Institute
# Research Analyst                            Twitter
# Research Analyst                           DCS Corp
# Research Analyst                Marcus & Associates
# Research Analyst                     Lockstep, Inc.
#
#                                                         description  \
# Research Analyst  <span id="job_summary" class="summary"><b>SUMM...
# Research Analyst  <span id="job_summary" class="summary"><p>Incu...
# Research Analyst  <span id="job_summary" class="summary">Respons...
# Research Analyst  <span id="job_summary" class="summary"><b>Abou...
# Research Analyst  <span id="job_summary" class="summary"><b>Over...
# ...
